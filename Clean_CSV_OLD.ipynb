# %%
#!pip install pandas
#!pip install plotly
#%pip install nbformat

# %%
import pandas as pd

file_path = "MisurazioniRAW/2025-11-22_07_59_influxdb_data.csv"
save_path = "2025-11-22.csv"

df_clean = pd.read_csv(file_path, skiprows=3)

# rimuovo colonne indesiderate (se presenti)
df_clean = df_clean.drop(columns=[col for col in df_clean.columns if "Unnamed" in col or col in ["result", "table", "_start", "_stop"]], errors='ignore')

pd.set_option("display.expand_frame_repr", False)  # niente wrapping
pd.set_option("display.max_columns", None)         # mostra tutte le colonne

print(df_clean.head())
df_clean.to_csv(save_path, index=False)

pd.reset_option("display.expand_frame_repr")
pd.reset_option("display.max_columns")
# Out:
#                       _time _measurement          host location    room   accel_x   accel_y   accel_z    gyro_x    gyro_y    gyro_z   humidity  is_moving  light        mic  temperature
# 0  2025-11-22T00:32:36.084Z    corso_IoT  ESP_LEOPIZZI    Lecce  Stanza -0.087895  0.117368  0.946316  9.357895 -4.573684 -1.448421  78.573684       50.0    0.0  33.000000    18.910526
# 1  2025-11-22T00:33:35.751Z    corso_IoT  ESP_LEOPIZZI    Lecce  Stanza -0.085652  0.118478  0.947609  9.542174 -4.413913 -1.483043  77.782609       50.0    0.0  28.673913    19.106522
# 2  2025-11-22T00:34:35.418Z    corso_IoT  ESP_LEOPIZZI    Lecce  Stanza -0.080000  0.119714  0.948857  9.338000 -4.596000 -1.510571  76.945714       50.0    0.0  21.628571    19.282857
# 3  2025-11-22T00:35:35.085Z    corso_IoT  ESP_LEOPIZZI    Lecce  Stanza -0.079104  0.120299  0.948209  9.369254 -4.549701 -1.410448  76.386567       50.0    0.0  25.940299    19.391045
# ...
